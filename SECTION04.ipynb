# %%
import pandas as pd

# Initial data
data1 = {'Make': ['CAN-AM'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-04602'], 
         'AD Item Number': ['679252'], 
         'Vendor Notes': ['"UNIVERSAL SEAT COVER MATERIAL. UV/WEATHER RESISTANT; UP-04130_FOR SIZE 36"" X 54""; UP-04130-1 (FOR SIZE 54"" X 72"")"'], 
         'REF#': ['708000538'], 
         'OEM#': [' ']
        }

# List of models
new_list_models = [
    
'Outlander 500 HO 4x4 EFI',
'Outlander 500 HO 4x4 EFI XT',
'Outlander 500 HO 4x4 EFI XT-P',
'Outlander 500 EFI XT',
'Outlander 500 EFI',
'Outlander 500 EFI DPS'
'Outlander 650 HO EFI 4x4',
'Outlander 650 HO EFI 4x4 XT',
'Outlander 650 HO 4x4 EFI',
'Outlander 650 HO 4x4 EFI XT',
'Outlander 650 EFI XT-P',
'Outlander 650 EFI XT',
'Outlander 650 EFI',
'Outlander 650 EFI DPS',
'Outlander 650 X mr',
'Outlander 650 6x6 XT',
'Outlander 650',
'Outlander 650 DPS',
'Outlander 650 XT',
'Outlander 650 6x6 DPS',
'Outlander 650 North Edition',
'Outlander 650 Mossy Oak Edition',
'Outlander 800 HO EFI 4x4',
'Outlander 800 HO EFI 4x4 XT',
'Outlander 800 HO 4x4 EFI',
'Outlander 800 HO 4x4 EFI',
'Outlander 800 HO 4x4 EFI XT',
'Outlander 800 HO 4x4 EFI XT',
'Outlander 800 HO 4x4 EFI',
'Outlander 800 HO 4x4 EFI XT',
'Outlander 800 HO 4x4 EFI',
'Outlander 800 HO 4x4 EFI XT'

]

oem_numbers = [pd.NA]

# Range of years
years = list(range(2006, 2014))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#        Make                          Model Vendor Code  \
# 0    CAN-AM       Outlander 500 HO 4x4 EFI        NACH
# 1    CAN-AM    Outlander 500 HO 4x4 EFI XT        NACH
# 2    CAN-AM  Outlander 500 HO 4x4 EFI XT-P        NACH
# 3    CAN-AM           Outlander 500 EFI XT        NACH
# 4    CAN-AM              Outlander 500 EFI        NACH
# ..      ...                            ...         ...
# 243  CAN-AM    Outlander 800 HO 4x4 EFI XT        NACH
# 244  CAN-AM       Outlander 800 HO 4x4 EFI        NACH
# 245  CAN-AM    Outlander 800 HO 4x4 EFI XT        NACH
# 246  CAN-AM       Outlander 800 HO 4x4 EFI        NACH
# 247  CAN-AM    Outlander 800 HO 4x4 EFI XT        NACH
#
#                       Vendor Name       MPN AD Item Number  \
# 0    NACHMAN INTERNATIONAL CO.LTD  AT-04602         679252
# 1    NACHMAN INTERNATIONAL CO.LTD  AT-04602         679252
# 2    NACHMAN INTERNATIONAL CO.LTD  AT-04602         679252
# 3    NACHMAN INTERNATIONAL CO.LTD  AT-04602         679252
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\01_Section 04 - Seat Cover\merge\1.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['HONDA'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-04610'], 
         'AD Item Number': ['679260'], 
         'Vendor Notes': ['"UNIVERSAL SEAT COVER MATERIAL. UV/WEATHER RESISTANT; UP-04130_FOR SIZE 36"" X 54""; UP-04130-1 (FOR SIZE 54"" X 72"")"'], 
         'REF#': ['30-13088-01'], 
         'OEM#': [' ']
        }

# List of models
new_list_models = [
    
'TRX300 FourTrax'


]

oem_numbers = [pd.NA]

# Range of years
years = list(range(1988, 2001))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#      Make            Model Vendor Code                   Vendor Name  \
# 0   HONDA  TRX300 FourTrax        NACH  NACHMAN INTERNATIONAL CO.LTD
# 1   HONDA  TRX300 FourTrax        NACH  NACHMAN INTERNATIONAL CO.LTD
# 2   HONDA  TRX300 FourTrax        NACH  NACHMAN INTERNATIONAL CO.LTD
# 3   HONDA  TRX300 FourTrax        NACH  NACHMAN INTERNATIONAL CO.LTD
# 4   HONDA  TRX300 FourTrax        NACH  NACHMAN INTERNATIONAL CO.LTD
# 5   HONDA  TRX300 FourTrax        NACH  NACHMAN INTERNATIONAL CO.LTD
# 6   HONDA  TRX300 FourTrax        NACH  NACHMAN INTERNATIONAL CO.LTD
# 7   HONDA  TRX300 FourTrax        NACH  NACHMAN INTERNATIONAL CO.LTD
# 8   HONDA  TRX300 FourTrax        NACH  NACHMAN INTERNATIONAL CO.LTD
# 9   HONDA  TRX300 FourTrax        NACH  NACHMAN INTERNATIONAL CO.LTD
# 10  HONDA  TRX300 FourTrax        NACH  NACHMAN INTERNATIONAL CO.LTD
# 11  HONDA  TRX300 FourTrax        NACH  NACHMAN INTERNATIONAL CO.LTD
# 12  HONDA  TRX300 FourTrax        NACH  NACHMAN INTERNATIONAL CO.LTD
#
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\01_Section 04 - Seat Cover\merge\2.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['HONDA'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-04611'], 
         'AD Item Number': ['679261'], 
         'Vendor Notes': ['"UNIVERSAL SEAT COVER MATERIAL. UV/WEATHER RESISTANT; UP-04130_FOR SIZE 36"" X 54""; UP-04130-1 (FOR SIZE 54"" X 72"")"'], 
         'REF#': ['30-13504-01'], 
         'OEM#': [' ']
        }

# List of models
new_list_models = [
    
'TRX350',
'TRX350D',
'TRX350FE FourTrax Rancher 4x4 ES',
'TRX350FM FourTrax Rancher 4X4',
'TRX350TE FourTrax Rancher ES',
'TRX350TM FourTrax Rancher',
'TRX400EX Sportrax',
'TRX400FA FourTrax Rancher AT',
'TRX400FGA FourTrax Rancher AT GPScape',
'TRX400FW Foreman 4x4',
'TRX400X'



]
oem_numbers = [pd.NA]

# Range of years
years = list(range(2004, 2008))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#      Make                                  Model Vendor Code  \
# 0   HONDA                                 TRX350        NACH
# 1   HONDA                                TRX350D        NACH
# 2   HONDA       TRX350FE FourTrax Rancher 4x4 ES        NACH
# 3   HONDA          TRX350FM FourTrax Rancher 4X4        NACH
# 4   HONDA           TRX350TE FourTrax Rancher ES        NACH
# 5   HONDA              TRX350TM FourTrax Rancher        NACH
# 6   HONDA                      TRX400EX Sportrax        NACH
# 7   HONDA           TRX400FA FourTrax Rancher AT        NACH
# 8   HONDA  TRX400FGA FourTrax Rancher AT GPScape        NACH
# 9   HONDA                   TRX400FW Foreman 4x4        NACH
# 10  HONDA                                TRX400X        NACH
# 11  HONDA                                 TRX350        NACH
# 12  HONDA                                TRX350D        NACH
# 13  HONDA       TRX350FE FourTrax Rancher 4x4 ES        NACH
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\01_Section 04 - Seat Cover\merge\3.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['HONDA'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-04615'], 
         'AD Item Number': ['679265'], 
         'Vendor Notes': ['"UNIVERSAL SEAT COVER MATERIAL. UV/WEATHER RESISTANT; UP-04130_FOR SIZE 36"" X 54""; UP-04130-1 (FOR SIZE 54"" X 72"")"'], 
         'REF#': ['30-14207-01'], 
         'OEM#': [' ']
        }

# List of models
new_list_models = [
    
'TRX420FA Rancher AT',
'TRX420FA2 FourTrax Rancher 4x4 Auto DCT with EPS',
'TRX420FA1 FourTrax Rancher 4x4 Auto DCT',
'TRX420FA5 FourTrax Rancher 4x4 Auto DCT IRS',
'TRX420FA6 FourTrax Rancher 4x4 Auto DCT IRS EPS',
'TRX420FE FourTrax Rancher 4X4 ES',
'TRX420FM FourTrax Rancher 4X4',
'TRX420FPA Rancher AT 4x4 w/ Power Steering',
'TRX420FPE Rancher ES 4x4 w/ Power Steering',
'TRX420FPM Rancher 4x4 w/ Power Steering',
'TRX420FM1 FourTrax Rancher 4x4',
'TRX420FE1 FourTrax Rancher 4x4 ES',
'TRX420FM2 FourTrax Rancher 4x4 with EPS',
'TRX420TE FourTrax Rancher ES',
'TRX420TM FourTrax Rancher'



]
oem_numbers = [pd.NA]

# Range of years
years = list(range(2007, 2014))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#       Make                                             Model Vendor Code  \
# 0    HONDA                               TRX420FA Rancher AT        NACH
# 1    HONDA  TRX420FA2 FourTrax Rancher 4x4 Auto DCT with EPS        NACH
# 2    HONDA           TRX420FA1 FourTrax Rancher 4x4 Auto DCT        NACH
# 3    HONDA       TRX420FA5 FourTrax Rancher 4x4 Auto DCT IRS        NACH
# 4    HONDA   TRX420FA6 FourTrax Rancher 4x4 Auto DCT IRS EPS        NACH
# ..     ...                                               ...         ...
# 100  HONDA                    TRX420FM1 FourTrax Rancher 4x4        NACH
# 101  HONDA                 TRX420FE1 FourTrax Rancher 4x4 ES        NACH
# 102  HONDA           TRX420FM2 FourTrax Rancher 4x4 with EPS        NACH
# 103  HONDA                      TRX420TE FourTrax Rancher ES        NACH
# 104  HONDA                         TRX420TM FourTrax Rancher        NACH
#
#                       Vendor Name       MPN AD Item Number  \
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\01_Section 04 - Seat Cover\merge\4.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['HONDA'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-04637'], 
         'AD Item Number': ['679287'], 
         'Vendor Notes': ['"UNIVERSAL SEAT COVER MATERIAL. UV/WEATHER RESISTANT; UP-04130_FOR SIZE 36"" X 54""; UP-04130-1 (FOR SIZE 54"" X 72"")"'], 
         'REF#': ['30-53396-01'], 
         'OEM#': [' ']
        }

# List of models
new_list_models = [
    
'Trail Boss 330',
'Sportsman 400',
'Sportsman 400 HO',
'Sportsman 400 4x4',
'Sportsman 400L',
'Sportsman 400 HO South Edition',
'Sportsman 500 4x4',
'Sportsman 500 6x6',
'Sportsman 500 EFI Touring',
'Sportsman 500 EFI X2',
'Sportsman 500 HO',
'Sportsman 500 EFI',
'Sportsman 500 EFI Deluxe',
'Sportsman 500 EFI X2 Deluxe',
'Sportsman 500 RSE',
'Sportsman 500 HO RSE',
'Sportsman 500 HO Touring',
'Sportsman 500 HO Polaris Pursuite LE',
'Sportsman 500 HO DUSE',
'Sportsman 600',
'Sportsman 700',
'Sportsman 700 EFI',
'Sportsman 700 EFI X2',
'Sportsman 700 MV'



]
oem_numbers = [pd.NA]

# Range of years
years = list(range(1996, 2010))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#       Make                 Model Vendor Code                   Vendor Name  \
# 0    HONDA        Trail Boss 330        NACH  NACHMAN INTERNATIONAL CO.LTD
# 1    HONDA         Sportsman 400        NACH  NACHMAN INTERNATIONAL CO.LTD
# 2    HONDA      Sportsman 400 HO        NACH  NACHMAN INTERNATIONAL CO.LTD
# 3    HONDA     Sportsman 400 4x4        NACH  NACHMAN INTERNATIONAL CO.LTD
# 4    HONDA        Sportsman 400L        NACH  NACHMAN INTERNATIONAL CO.LTD
# ..     ...                   ...         ...                           ...
# 331  HONDA         Sportsman 600        NACH  NACHMAN INTERNATIONAL CO.LTD
# 332  HONDA         Sportsman 700        NACH  NACHMAN INTERNATIONAL CO.LTD
# 333  HONDA     Sportsman 700 EFI        NACH  NACHMAN INTERNATIONAL CO.LTD
# 334  HONDA  Sportsman 700 EFI X2        NACH  NACHMAN INTERNATIONAL CO.LTD
# 335  HONDA      Sportsman 700 MV        NACH  NACHMAN INTERNATIONAL CO.LTD
#
#           MPN AD Item Number  \
# 0    AT-04637         679287
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\01_Section 04 - Seat Cover\merge\5.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         'MPN': ['AT-04638'], 
         'AD Item Number': ['679288'], 
         'Vendor Notes': ['"UNIVERSAL SEAT COVER MATERIAL. UV/WEATHER RESISTANT; UP-04130_FOR SIZE 36"" X 54""; UP-04130-1 (FOR SIZE 54"" X 72"")"'], 
         'REF#': ['30-55005-01'], 
         'OEM#': [' ']
        }

# List of models
new_list_models = [
    
'Hawkeye 4x4',
'Hawkeye 2x4',
'Sportsman 400',
'Sportsman 400 HO',
'Sportsman 400 4x4',
'Sportsman 400L',
'Sportsman 400 HO South Edition',
'Sportsman 450',
'Sportsman 450 HO',
'Sportsman 450 HO EPS',
'Sportsman 450 HO Utility Edition',
'Sportsman 450 HO Utility',
'Sportsman 500 4x4',
'Sportsman 500 6x6',
'Sportsman 500 EFI Touring',
'Sportsman 500 EFI X2',
'Sportsman 500 HO',
'Sportsman 500 EFI',
'Sportsman 500 EFI Deluxe',
'Sportsman 500 EFI X2 Deluxe',
'Sportsman 500 RSE',
'Sportsman 500 HO RSE',
'Sportsman 500 HO Touring',
'Sportsman 500 HO Polaris Pursuite LE',
'Sportsman 500 HO DUSE',
'Sportsman 700',
'Sportsman 700 EFI',
'Sportsman 700 EFI X2',
'Sportsman 700 MV',
'Sportsman 800 EFI',
'Sportsman 800 EFI HO',
'Sportsman 800 EFI Touring',
'Sportsman 800 EFI Deluxe',
'Sportsman 800 EFI X2 Deluxe',
'Sportsman 800 EFI X2',
'Sportsman 800 EFI 6x6 Big Boss',
'Sportsman 800 HO EFI Military',
'Sportsman 800 6x6 Big Boss'




]
oem_numbers = [pd.NA]

# Range of years
years = list(range(2005, 2015))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#         Make                           Model Vendor Code  \
# 0    POLARIS                     Hawkeye 4x4        NACH
# 1    POLARIS                     Hawkeye 2x4        NACH
# 2    POLARIS                   Sportsman 400        NACH
# 3    POLARIS                Sportsman 400 HO        NACH
# 4    POLARIS               Sportsman 400 4x4        NACH
# ..       ...                             ...         ...
# 375  POLARIS     Sportsman 800 EFI X2 Deluxe        NACH
# 376  POLARIS            Sportsman 800 EFI X2        NACH
# 377  POLARIS  Sportsman 800 EFI 6x6 Big Boss        NACH
# 378  POLARIS   Sportsman 800 HO EFI Military        NACH
# 379  POLARIS      Sportsman 800 6x6 Big Boss        NACH
#
#                       Vendor Name       MPN AD Item Number  \
# 0    NACHMAN INTERNATIONAL CO.LTD  AT-04638         679288
# 1    NACHMAN INTERNATIONAL CO.LTD  AT-04638         679288
# 2    NACHMAN INTERNATIONAL CO.LTD  AT-04638         679288
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\01_Section 04 - Seat Cover\merge\6.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         
         'MPN': ['AT-04639'], 
         'AD Item Number': ['679289'], 
         'Vendor Notes': ['"UNIVERSAL SEAT COVER MATERIAL. UV/WEATHER RESISTANT; UP-04130_FOR SIZE 36"" X 54""; UP-04130-1 (FOR SIZE 54"" X 72"")"'], 
         'REF#': [['2684702', '2684701']],  # List containing multiple reference numbers
         'OEM#': [' ']
        }

# List of models
new_list_models = [
   'Sportsman 550 EFI XP',
'Sportsman 550 EFI XP w/ EPS',
'Sportsman 550 X2',
'Sportsman 550 EFI Touring w/ EPS',
'Sportsman 550 EFI',
'Sportsman 550 EFI w/ EPS',
'Sportsman 550 EPS Browning LE',
'Sportsman 550 Touring EPS',
'Sportsman 550 EPS Orange Madness LE',
'Sportsman 550 EPS',
'Sportsman 550',
'Sportsman 550 EPS Stealth Black LE',
'Sportsman 550 X2 EPS',
'Sportsman 850 EFI XP',
'Sportsman 850 EFI XP w/ EPS',
'Sportsman 850 EFI Touring EPS',
'Sportsman 850 EFI X2',
'Sportsman 850 HO Touring EPS Bronze Mist LE',
'Sportsman 850 HO XP EPS Browning LE',
'Sportsman 850 HO Touring EPS',
'Sportsman 850 HO XP EPS',
'Sportsman 850 HO XP EPS Orange Madness LE',
'Sportsman 850 HO XP',
'Sportsman 850 HO XP EPS Stealth Black LE',
'Sportsman 850 HO Touring EPS Sunset Red LE',
'Sportsman 850 HO XP EPS Pearl White LE',
'Sportsman 850 SP',
'Sportsman 850 Touring SP',
'Sportsman 850 High Lifter Edition',
'Sportsman 850 Premium',
'Sportsman 850 Touring',
'Sportsman 850 Ultimate Trail',
'Sportsman 1000 XP',
'Sportsman 1000 XP Hunter Edition',
'Sportsman 1000 XP High Lifter Edition',
'Sportsman 1000 XP Premium',
'Sportsman 1000 XP S',
'Sportsman 1000 XP Hunt Edition',
'Sportsman 1000 XP Ultimate Trail',
'Sportsman 1000 XP Ride Command Edition'

]

oem_numbers = [pd.NA]

# Range of years
years = list(range(2005, 2015))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#         Make                                   Model Vendor Code  \
# 0    POLARIS                    Sportsman 550 EFI XP        NACH
# 1    POLARIS             Sportsman 550 EFI XP w/ EPS        NACH
# 2    POLARIS                        Sportsman 550 X2        NACH
# 3    POLARIS        Sportsman 550 EFI Touring w/ EPS        NACH
# 4    POLARIS                       Sportsman 550 EFI        NACH
# ..       ...                                     ...         ...
# 395  POLARIS               Sportsman 1000 XP Premium        NACH
# 396  POLARIS                     Sportsman 1000 XP S        NACH
# 397  POLARIS          Sportsman 1000 XP Hunt Edition        NACH
# 398  POLARIS        Sportsman 1000 XP Ultimate Trail        NACH
# 399  POLARIS  Sportsman 1000 XP Ride Command Edition        NACH
#
#                       Vendor Name       MPN AD Item Number  \
# 0    NACHMAN INTERNATIONAL CO.LTD  AT-04639         679289
# 1    NACHMAN INTERNATIONAL CO.LTD  AT-04639         679289
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\01_Section 04 - Seat Cover\merge\7.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['SUZUKI'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         
         'MPN': ['AT-04649'], 
         'AD Item Number': ['679299'], 
         'Vendor Notes': ['"UNIVERSAL SEAT COVER MATERIAL. UV/WEATHER RESISTANT; UP-04130_FOR SIZE 36"" X 54""; UP-04130-1 (FOR SIZE 54"" X 72"")"'], 
         'REF#': [['30-33005-01']],  # List containing multiple reference numbers
         'OEM#': [' ']
        }

# List of models
new_list_models = [
'LT-A450X KingQuad AXi 4x4',' '
'LT-A500 KingQuad AXi',
'LT-A500 KingQuad AXi Power Steering',
'LT-A500 KingQuad AXi Power Steering SE',
'LT-A500 KingQuad AXi Power Steering SE Rugged',
'LT-A500 KingQuad AXi Power Steering SE+',
'LT-A500 KingQuad AXi Power Steering Rugged',
'LT-A500 KingQuad AXi Power Steering SE+ Rugged',
'LT-A750 KingQuad AXi Power Steering',
'LT-A750 KingQuad AXi Power Steering LE',
'LT-A750 KingQuad AXi Power Steering SE',
'LT-A750 KingQuad AXi Power Steering SE Rugged',
'LT-A750 KingQuad AXi Power Steering SE+',
'LT-A750 KingQuad AXi Power Steering Rugged',
'LT-A750 KingQuad AXi Power Steering SE+ Rugged'


]

oem_numbers = [pd.NA]

# Range of years
years = list(range(2005, 2019))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#        Make                                           Model Vendor Code  \
# 0    SUZUKI                       LT-A450X KingQuad AXi 4x4        NACH
# 1    SUZUKI                            LT-A500 KingQuad AXi        NACH
# 2    SUZUKI             LT-A500 KingQuad AXi Power Steering        NACH
# 3    SUZUKI          LT-A500 KingQuad AXi Power Steering SE        NACH
# 4    SUZUKI   LT-A500 KingQuad AXi Power Steering SE Rugged        NACH
# ..      ...                                             ...         ...
# 205  SUZUKI          LT-A750 KingQuad AXi Power Steering SE        NACH
# 206  SUZUKI   LT-A750 KingQuad AXi Power Steering SE Rugged        NACH
# 207  SUZUKI         LT-A750 KingQuad AXi Power Steering SE+        NACH
# 208  SUZUKI      LT-A750 KingQuad AXi Power Steering Rugged        NACH
# 209  SUZUKI  LT-A750 KingQuad AXi Power Steering SE+ Rugged        NACH
#
#                       Vendor Name       MPN AD Item Number  \
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\01_Section 04 - Seat Cover\merge\8.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['SUZUKI'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         
         'MPN': ['AT-04658'], 
         'AD Item Number': ['679308'], 
         'Vendor Notes': ['"UNIVERSAL SEAT COVER MATERIAL. UV/WEATHER RESISTANT; UP-04130_FOR SIZE 36"" X 54""; UP-04130-1 (FOR SIZE 54"" X 72"")"'], 
         'REF#': [['30-44000-01']],  # List containing multiple reference numbers
         'OEM#': [' ']
        }

# List of models
new_list_models = [

    
'YFM250 Big Bear',
'YFM250 Bruin',
'YFM350 Bruin Auto 2x4',
'YFM350 Grizzly 4x4 Auto',
'YFM350 Grizzly Auto',
'YFM350 Grizzly IRS 4x4 Auto',
'YFM400 Grizzly 4x4 Auto',
'YFM450 Grizzly 4x4 Auto',
'YFM450 Grizzly 4x4 Auto IRS',
'YFM450 Grizzly 4x4 Auto EPS',
'YFM450 Kodiak 450',
'YFM450 Kodiak 450 EPS',
'YFM450 Kodiak 450 EPS SE'



]

oem_numbers = [pd.NA]

# Range of years
years = list(range(2003, 2015))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#        Make                        Model Vendor Code  \
# 0    SUZUKI              YFM250 Big Bear        NACH
# 1    SUZUKI                 YFM250 Bruin        NACH
# 2    SUZUKI        YFM350 Bruin Auto 2x4        NACH
# 3    SUZUKI      YFM350 Grizzly 4x4 Auto        NACH
# 4    SUZUKI          YFM350 Grizzly Auto        NACH
# ..      ...                          ...         ...
# 151  SUZUKI  YFM450 Grizzly 4x4 Auto IRS        NACH
# 152  SUZUKI  YFM450 Grizzly 4x4 Auto EPS        NACH
# 153  SUZUKI            YFM450 Kodiak 450        NACH
# 154  SUZUKI        YFM450 Kodiak 450 EPS        NACH
# 155  SUZUKI     YFM450 Kodiak 450 EPS SE        NACH
#
#                       Vendor Name       MPN AD Item Number  \
# 0    NACHMAN INTERNATIONAL CO.LTD  AT-04658         679308
# 1    NACHMAN INTERNATIONAL CO.LTD  AT-04658         679308
# 2    NACHMAN INTERNATIONAL CO.LTD  AT-04658         679308
# 3    NACHMAN INTERNATIONAL CO.LTD  AT-04658         679308
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\01_Section 04 - Seat Cover\merge\9.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         
         'MPN': ['AT-04663'], 
         'AD Item Number': ['679313'], 
         'Vendor Notes': ['"UNIVERSAL SEAT COVER MATERIAL. UV/WEATHER RESISTANT; UP-04130_FOR SIZE 36"" X 54""; UP-04130-1 (FOR SIZE 54"" X 72"")"'], 
         'REF#': [['30-43587-01']],  # List containing multiple reference numbers
         'OEM#': [' ']
        }

# List of models
new_list_models = [

    
'YFZ350 Banshee'




]

oem_numbers = [pd.NA]

# Range of years
years = list(range(1987, 2007))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#       Make           Model Vendor Code                   Vendor Name  \
# 0   YAMAHA  YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO.LTD
# 1   YAMAHA  YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO.LTD
# 2   YAMAHA  YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO.LTD
# 3   YAMAHA  YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO.LTD
# 4   YAMAHA  YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO.LTD
# 5   YAMAHA  YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO.LTD
# 6   YAMAHA  YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO.LTD
# 7   YAMAHA  YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO.LTD
# 8   YAMAHA  YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO.LTD
# 9   YAMAHA  YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO.LTD
# 10  YAMAHA  YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO.LTD
# 11  YAMAHA  YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO.LTD
# 12  YAMAHA  YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO.LTD
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\01_Section 04 - Seat Cover\merge\10.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['YAMAHA'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         
         'MPN': ['AT-04668'], 
         'AD Item Number': ['679318'], 
         'Vendor Notes': ['"UNIVERSAL SEAT COVER MATERIAL. UV/WEATHER RESISTANT; UP-04130_FOR SIZE 36"" X 54""; UP-04130-1 (FOR SIZE 54"" X 72"")"'], 
         'REF#': [['30-47007-01']],  # List containing multiple reference numbers
         'OEM#': [' ']
        }

# List of models
new_list_models = [

    
'YFZ350 Banshee',
'YFM550 Grizzly FI 4x4 Auto',
'YFM550 Grizzly FI 4x4 Auto EPS',
'YFM700 Grizzly FI 4x4 Auto',
'YFM700 Grizzly FI 4x4 Auto EPS',
'YFM700 Grizzly FI 4x4 Auto EPS SE',
'YFM700 Grizzly EPS LE',
'YFM700 Grizzly EPS',
'YFM700 Grizzly EPS SE',
'YFM700 Grizzly EPS XT-R'

]

oem_numbers = [pd.NA]

# Range of years
years = list(range(2007, 2016))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#       Make                              Model Vendor Code  \
# 0   YAMAHA                     YFZ350 Banshee        NACH
# 1   YAMAHA         YFM550 Grizzly FI 4x4 Auto        NACH
# 2   YAMAHA     YFM550 Grizzly FI 4x4 Auto EPS        NACH
# 3   YAMAHA         YFM700 Grizzly FI 4x4 Auto        NACH
# 4   YAMAHA     YFM700 Grizzly FI 4x4 Auto EPS        NACH
# ..     ...                                ...         ...
# 85  YAMAHA  YFM700 Grizzly FI 4x4 Auto EPS SE        NACH
# 86  YAMAHA              YFM700 Grizzly EPS LE        NACH
# 87  YAMAHA                 YFM700 Grizzly EPS        NACH
# 88  YAMAHA              YFM700 Grizzly EPS SE        NACH
# 89  YAMAHA            YFM700 Grizzly EPS XT-R        NACH
#
#                      Vendor Name       MPN AD Item Number  \
# 0   NACHMAN INTERNATIONAL CO.LTD  AT-04668         679318
# 1   NACHMAN INTERNATIONAL CO.LTD  AT-04668         679318
# 2   NACHMAN INTERNATIONAL CO.LTD  AT-04668         679318
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\01_Section 04 - Seat Cover\merge\11.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         
         'MPN': ['AT-04679'], 
         'AD Item Number': ['129316'], 
         'Vendor Notes': ['"UNIVERSAL SEAT COVER MATERIAL. UV/WEATHER RESISTANT; UP-04130_FOR SIZE 36"" X 54""; UP-04130-1 (FOR SIZE 54"" X 72"")"'], 
         'REF#': [['2688353']], 
         'OEM#': [' ']
        }

# List of models
new_list_models = [

    
'Sportsman 450',
'Sportsman 450 HO',
'Sportsman 450 HO EPS',
'Sportsman 450 HO Utility Edition',
'Sportsman 450 HO Utility',
'Sportsman 570',
'Sportsman 570 EPS',
'Sportsman 570 Touring',
'Sportsman 570 SP',
'Sportsman 570 SP Hunters Edition',
'Sportsman 570 Touring SP',
'Sportsman 570 X2 EPS',
'Sportsman 570 Touring EPS',
'Sportsman 570 Big Boss 6x6 EPS',
'Sportsman 570 EPS Utility Edition',
'Sportsman 570 6x6',
'Sportsman 570 Hunter Edition',
'Sportsman 570 Premium',
'Sportsman 570 Touring Premium',
'Sportsman 570 X2',
'Sportsman 570 Trail',
'Sportsman 570 Utility HD LE',
'Sportsman 570 Hunt Edition',
'Sportsman 570 Ultimate Trail LE',
'Sportsman 570 EPS Utility',
'Sportsman 570 Utility HD',
'Sportsman 570 Ride Command Limited Edition'


]

oem_numbers = [pd.NA]

# Range of years
years = list(range(2018, 2021))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#        Make                                       Model Vendor Code  \
# 0   POLARIS                               Sportsman 450        NACH
# 1   POLARIS                            Sportsman 450 HO        NACH
# 2   POLARIS                        Sportsman 450 HO EPS        NACH
# 3   POLARIS            Sportsman 450 HO Utility Edition        NACH
# 4   POLARIS                    Sportsman 450 HO Utility        NACH
# ..      ...                                         ...         ...
# 76  POLARIS                  Sportsman 570 Hunt Edition        NACH
# 77  POLARIS             Sportsman 570 Ultimate Trail LE        NACH
# 78  POLARIS                   Sportsman 570 EPS Utility        NACH
# 79  POLARIS                    Sportsman 570 Utility HD        NACH
# 80  POLARIS  Sportsman 570 Ride Command Limited Edition        NACH
#
#                      Vendor Name       MPN AD Item Number  \
# 0   NACHMAN INTERNATIONAL CO.LTD  AT-04679         129316
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\01_Section 04 - Seat Cover\merge\12.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['POLARIS'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         
         'MPN': ['AT-04680'], 
         'AD Item Number': ['129317'], 
         'Vendor Notes': ['"UNIVERSAL SEAT COVER MATERIAL. UV/WEATHER RESISTANT; UP-04130_FOR SIZE 36"" X 54""; UP-04130-1 (FOR SIZE 54"" X 72"")"'], 
         'REF#': [['2687924']], 
         'OEM#': [' ']
        }

# List of models
new_list_models = [

    
'Sportsman 850 EFI XP',
'Sportsman 850 EFI XP w/ EPS',
'Sportsman 850 EFI Touring EPS',
'Sportsman 850 EFI X2',
'Sportsman 850 HO Touring EPS Bronze Mist LE',
'Sportsman 850 HO XP EPS Browning LE',
'Sportsman 850 HO Touring EPS',
'Sportsman 850 HO XP EPS',
'Sportsman 850 HO XP EPS Orange Madness LE',
'Sportsman 850 HO XP',
'Sportsman 850 HO XP EPS Stealth Black LE',
'Sportsman 850 HO Touring EPS Sunset Red LE',
'Sportsman 850 HO XP EPS Pearl White LE',
'Sportsman 850',
'Sportsman 850 SP',
'Sportsman 850 Touring SP',
'Sportsman 850 High Lifter Edition',
'Sportsman 850 Premium',
'Sportsman 850 Touring',
'Sportsman 850 Ultimate Trail',
'Sportsman 1000 XP',
'Sportsman 1000 Touring XP',
'Sportsman 1000 XP Hunter Edition',
'Sportsman 1000 Touring XP Limited',
'Sportsman 1000 XP High Lifter Edition',
'Sportsman 1000 XP Premium',
'Sportsman 1000 XP S',
'Sportsman 1000 XP Hunt Edition',
'Sportsman 1000 XP Ultimate Trail',
'Sportsman 1000 XP Ride Command Edition'



]

oem_numbers = [pd.NA]

# Range of years
years = list(range(2017, 2024))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#         Make                                        Model Vendor Code  \
# 0    POLARIS                         Sportsman 850 EFI XP        NACH
# 1    POLARIS                  Sportsman 850 EFI XP w/ EPS        NACH
# 2    POLARIS                Sportsman 850 EFI Touring EPS        NACH
# 3    POLARIS                         Sportsman 850 EFI X2        NACH
# 4    POLARIS  Sportsman 850 HO Touring EPS Bronze Mist LE        NACH
# ..       ...                                          ...         ...
# 205  POLARIS                    Sportsman 1000 XP Premium        NACH
# 206  POLARIS                          Sportsman 1000 XP S        NACH
# 207  POLARIS               Sportsman 1000 XP Hunt Edition        NACH
# 208  POLARIS             Sportsman 1000 XP Ultimate Trail        NACH
# 209  POLARIS       Sportsman 1000 XP Ride Command Edition        NACH
#
#                       Vendor Name       MPN AD Item Number  \
# 0    NACHMAN INTERNATIONAL CO.LTD  AT-04680         129317
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\01_Section 04 - Seat Cover\merge\13.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

# Initial data
data1 = {'Make': ['CAN-AM'], 'Model': ['all models'], 'Vendor Code': ['NACH'], 'Vendor Name': ['NACHMAN INTERNATIONAL CO.LTD'],
         
         'MPN': ['AT-04681'], 
         'AD Item Number': ['129314'], 
         'Vendor Notes': ['"UNIVERSAL SEAT COVER MATERIAL. UV/WEATHER RESISTANT; UP-04130_FOR SIZE 36"" X 54""; UP-04130-1 (FOR SIZE 54"" X 72"")"'], 
         'REF#': [['708000724']], 
         'OEM#': [' ']
        }

# List of models
new_list_models = [

    
'Outlander 450',
'Outlander 450 DPS',
'Outlander 450 Mossy Oak Hunting Edition',
'Outlander 450 Mossy Oak Edition',
'Outlander 500 HO 4x4 EFI',
'Outlander 500 HO 4x4 EFI XT',
'Outlander 500 HO 4x4 EFI XT-P',
'Outlander 500 EFI XT',
'Outlander 500 EFI',
'Outlander 500 EFI DPS',
'Outlander 570 DPS',
'Outlander 570 XT',
'Outlander 570',
'Outlander 570 Mossy Oak Hunting Edition',
'Outlander 570 X mr',
'Outlander 570 Mossy Oak Edition',
'Outlander 570 mr',
'Outlander 650 HO EFI 4x4',
'Outlander 650 HO EFI 4x4 XT',
'Outlander 650 HO 4x4 EFI',
'Outlander 650 HO 4x4 EFI XT',
'Outlander 650 EFI XT-P',
'Outlander 650 EFI XT',
'Outlander 650 EFI',
'Outlander 650 EFI DPS',
'Outlander 650 X mr',
'Outlander 650 6x6 XT',
'Outlander 650',
'Outlander 650 DPS',
'Outlander 650 XT',
'Outlander 650 6x6 DPS',
'Outlander 650 North Edition',
'Outlander 650 Mossy Oak Edition',
'Outlander 800 HO EFI 4x4',
'Outlander 800 HO EFI 4x4 XT',
'Outlander 800 HO 4x4 EFI',
'Outlander 800 HO 4x4 EFI XT',
'Outlander 800R EFI XT-P',
'Outlander 800R EFI X xc',
'Outlander 800R EFI XT',
'Outlander 800R EFI',
'Outlander 800R EFI X mr',
'Outlander 800R EFI DPS',
'Outlander 850 DPS',
'Outlander 850 XT',
'Outlander 850 XT-P',
'Outlander 850 X mr',
'Outlander 850 North Edition',
'Outlander 850',
'Outlander 1000 EFI XT',
'Outlander 1000 EFI',
'Outlander 1000 EFI DPS',
'Outlander 1000 EFI XT-P',
'Outlander 1000 X mr',
'Outlander 1000 6x6 XT',
'Outlander 1000 DPS',
'Outlander 1000 XT',
'Outlander 1000 XT-P',
'Outlander 1000 Mossy Oak Hunting Edition',
'Outlander 1000 X xc'


]

oem_numbers = [pd.NA]

# Range of years
years = list(range(2012, 2024))

# Function to generate DataFrame for each model
def generate_df(model, data, year):
    data_copy = data.copy()  # Create a copy of data1 to avoid modifying the original dictionary
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

# Generate DataFrames for all sets of data
dfs = []
for year in years:
    for oem in oem_numbers:
        data1['OEM#'] = oem
        df1 = pd.concat([generate_df(model, data1, year) for model in new_list_models], ignore_index=True)
        dfs.append(df1)

# Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

# Print the final DataFrame
final_df
# Out:
#        Make                                     Model Vendor Code  \
# 0    CAN-AM                             Outlander 450        NACH
# 1    CAN-AM                         Outlander 450 DPS        NACH
# 2    CAN-AM   Outlander 450 Mossy Oak Hunting Edition        NACH
# 3    CAN-AM           Outlander 450 Mossy Oak Edition        NACH
# 4    CAN-AM                  Outlander 500 HO 4x4 EFI        NACH
# ..      ...                                       ...         ...
# 715  CAN-AM                        Outlander 1000 DPS        NACH
# 716  CAN-AM                         Outlander 1000 XT        NACH
# 717  CAN-AM                       Outlander 1000 XT-P        NACH
# 718  CAN-AM  Outlander 1000 Mossy Oak Hunting Edition        NACH
# 719  CAN-AM                       Outlander 1000 X xc        NACH
#
#                       Vendor Name       MPN AD Item Number  \
# 0    NACHMAN INTERNATIONAL CO.LTD  AT-04681         129314
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\01_Section 04 - Seat Cover\merge\14.csv"
final_df.to_csv(file_path, index=False)
